# %% [markdown]
# # Introduction
# In this notebook I will simplify the english->swedish translation task I have been tackeling in previous notebooks by limiting my data to sentences with a limited structure.
#
# In the [PyTorch tutorial](https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html#sphx-glr-download-intermediate-seq2seq-translation-tutorial-py) that I have been inspired by they limit their task to sentences start with "i am", "she is", "we are" etc.
#
# Let's see if we have enough data in the english->swedish data set to use such a simplification.

# %% [markdown]
# # Data
# Data from: http://www.manythings.org/anki/.

# %%
data_path = 'data/swe-eng/swe.txt'
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

# %% [markdown]
# Read all sentences.

# %%
input_sentences, target_sentences = [], []
for line in lines:
    try:
        input_text, target_text, *_ = line.split('\t')
    except ValueError:
        print(line)
        
    input_sentences.append(input_text)
    target_sentences.append(target_text)

# %% [markdown]
# ## Tokenize and Normalise
# I want to word tokenize by using NLTK, and then convert to lower case.

# %%
from nltk.tokenize import word_tokenize

# %%
input_tokenized = [list(map(str.lower, word_tokenize(sentence))) for sentence in input_sentences]
target_tokenized = [list(map(str.lower, word_tokenize(sentence, language='swedish'))) for sentence in target_sentences]

# %%
input_tokenized[0]
# Out:
# ['run', '!']

# %% [markdown]
# ## Limit sentence structure
# Let's try the same limitations used in the PyTorch tutorial and see if we get enough data.

# %%
word_tokenize("I'm")
# Out:
# ['I', "'m"]

# %%
eng_prefixes = [
    ["i",  "am"],
    ["i", "'m"],
    ["he", "is"],
    ["he", "'s"],
    ["she", "is"],
    ["she", "'s"],
    ["you", "are"],
    ["you" "'re"],
    ["we", "are"], 
    ["we", "'re"],
    ["they", "are"],
    ["they","'re"]
]

# %%
def matches_prefix(sentence, prefixes):
    for prefix in prefixes:
        if prefix == sentence[:len(prefix)]:
            return True
    return False

# %%
import numpy as np

# %%
match_idx = np.where(np.array([matches_prefix(sentence, eng_prefixes) for sentence in input_tokenized]))

# %%
print("%d sentences matching our prefix list" % len(match_idx[0]))
# Out:
# 1073 sentences matching our prefix list

# %% [markdown]
# Not that many matching sentences, but let's attempt this limited problem. At least training will be faster.

# %%
input_sentences = np.array(input_tokenized)[match_idx]
target_sentences = np.array(target_tokenized)[match_idx]

# %% [markdown]
# ## Limit sentence length

# %%
input_seq_lens = np.array([len(sentence) for sentence in input_sentences])
target_seq_lens = np.array([len(sentence) for sentence in target_sentences])

# %%
max_seq_len = 10

# %%
input_idx = np.where(input_seq_lens <= max_seq_len)
target_idx = np.where(target_seq_lens <= max_seq_len)

# %%
print("{} input sentences with {} or fewer characters".format(len(input_idx[0]), max_seq_len))
print("{} target sentences with {} or fewer characters".format(len(target_idx[0]), max_seq_len))
# Out:
# 1032 input sentences with 10 or fewer characters
# 1042 target sentences with 10 or fewer characters

# %%
keep_idx = np.intersect1d(input_idx, target_idx)

# %%
print("{} input sentence pairs with {} or fewer characters in both languages".format(len(keep_idx), max_seq_len))
# Out:
# 1025 input sentence pairs with 10 or fewer characters in both languages

# %% [markdown]
# I barely lose any data by limiting to 10 words per sentence.

# %%
input_sentences = np.array(input_sentences)[keep_idx]
target_sentences = np.array(target_sentences)[keep_idx]

# %% [markdown]
# ## Build vocabularies
# I'll pretty much copy the approach of the PyTorch tutorial to construct my vocabularies. Just doing some small code tweaks.

# %%
class Vocab:
    
    def __init__(self, name):
        self.name = name
        self.word2index = {"<SOS>" : 0, "<EOS>" : 1}
        self.word2count = {}
        # Reverse word2index
        self.index2word = dict([(b, a) for a, b in self.word2index.items()])
        self.n_words = len(self.word2index)
        
    def add_sentence(self, sentence):
        for word in sentence:
            self.add_word(word)
        
    def add_word(self, word):
        # If there any many more tokens than unique tokens, 
        # it is more efficient to assume the token is already in the vocabulary
        try:
            self.word2count[word] += 1
        except KeyError:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1

# %%
input_vocab = Vocab('eng')
target_vocab = Vocab('swe')

# %%
# %%time
for input_sentence, target_sentence in zip(input_sentences, target_sentences):
    input_vocab.add_sentence(input_sentence)
    target_vocab.add_sentence(target_sentence)
# Out:
# Wall time: 12 ms

# %%
for vocab in [input_vocab, target_vocab]:
    print("Vocab %s: %d unique tokens and %d tokens total" % (vocab.name, vocab.n_words, sum(vocab.word2count.values())))
# Out:
# Vocab eng: 845 unique tokens and 6337 tokens total
# Vocab swe: 992 unique tokens and 5982 tokens total

# %% [markdown]
# ## Divide data into a training and a validation set
# I will use 800 sentances as training set and the remaining 225 as validation set.

# %%
trainig_size, validation_size = 800, len(input_sentences)-800

# %%
shuffle_idx = np.random.permutation(len(input_sentences))

# %%
train_idx, val_idx = shuffle_idx[:trainig_size], shuffle_idx[trainig_size:trainig_size+validation_size]

# %%
input_train, input_val = input_sentences[train_idx], input_sentences[val_idx]
target_train, target_val = target_sentences[train_idx], target_sentences[val_idx]

# %% [markdown]
# ## Convert data to tensors
# Just like in the PyTorch tutorial I will set up functions to convert the sentences to tensors.

# %%
import torch

# %%
def sentence2indexes(vocab, sentence):
    return [vocab.word2index[word] for word in sentence]


def sentence2tensor(vocab, sentence):
    indexes = sentence2indexes(vocab, sentence)
    indexes.append(vocab.word2index['<EOS>'])
    return torch.tensor(indexes, dtype=torch.long).view(-1, 1)


def pair2tensor(pair):
    input_tensor = sentence2tensor(input_vocab, pair[0])
    target_tensor = sentence2tensor(target_vocab, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# # Model
# Let's use the same model as in my last notebook.

# %% [markdown]
# ## Encoder

# %%
import torch.nn as nn

# %%
class EncoderRNN(nn.Module):
    def __init__(self, vocab_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        
        self.embedding = nn.Embedding(vocab_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        
    def forward(self, input_word, hidden_state):
        embedded = self.embedding(input_word).view(1, 1, -1)
        output, hidden_state = self.gru(embedded, hidden_state)
        return output, hidden_state
    
    # Returns a tensor with only zeroes to be used as initial hidden state
    def init_hidden(self):
        return torch.zeros(1, 1, self.hidden_size)

# %% [markdown]
# ## Decoder

# %%
import torch.nn.functional as F

# %%
class DecoderRNNAttention(nn.Module):
    def __init__(self, vocab_size, hidden_size, dropout_p, max_length):
        super(DecoderRNNAttention, self).__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        self.dropout_p = dropout_p
        self.max_length = max_length
        
        self.embedding = nn.Embedding(vocab_size, hidden_size)
        self.dropout = nn.Dropout(dropout_p)
        self.attention = nn.Linear(hidden_size * 2, max_length)
        self.attention_combine = nn.Linear(hidden_size * 2, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.output = nn.Linear(hidden_size, vocab_size)
        
    def forward(self, input_word, hidden_state, encoder_outputs):
        
        embedded = self.embedding(input_word).view(1, 1, -1)
        embedded = self.dropout(embedded)
        
        attention_weights = F.softmax(
            self.attention(torch.cat((embedded[0], hidden_state[0]), dim = 1)),
            dim = 1
        )
        
        attention_applied = torch.bmm(attention_weights.unsqueeze(0), encoder_outputs.unsqueeze(0))
        
        output = torch.cat((embedded[0], attention_applied[0]), dim=1)
        output = self.attention_combine(output).unsqueeze(0)
        
        output = F.relu(output)
        output, hidden_state = self.gru(output, hidden_state)
        
        output = F.log_softmax(self.output(output[0]), dim=1)
        return output, hidden_state, attention_weights
    
    # Returns a tensor with only zeroes to be used as initial hidden state
    def init_hidden(self):
        return torch.zeros(1, 1, self.hidden_size)

# %% [markdown]
# # Training
# The way I set up the model it can only train on one sentance at a time. This will probably add significant overhead, but tackeling that is a task for another day.
#
# As in all my previous notebooks I will use teacher forcing to train. However, this time I am able to introduce a new variant! As suggested in the PyTorch tutorial it's possible to alternate between teacher forcing and feeding the previous output as input.

# %%
import random

# %%
def train_model(encoder, decoder, input_tensor, target_tensor, encoder_optimizer, 
                decoder_optimizer, criterion, max_length, teacher_forcing_ratio = 1.0):
    
    encoder_hidden_state = encoder.init_hidden()
    
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()
    
    input_length = input_tensor.shape[0]
    target_length = target_tensor.shape[0]
    
    encoder_outputs = torch.zeros(max_length, encoder.hidden_size)
    
    loss = 0
    
    # Encode input tensor
    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden_state)
        encoder_outputs[ei] = encoder_output
        
    # Decode input tensor, seeding the decoding with the <BOS> token
    decoder_input = torch.tensor([[target_vocab.word2index['<SOS>']]])
    decoder_hidden_state = encoder_hidden_state
    
    # Use teacher-forcing according to dice roll
    use_teacher_forcing = random.random() < teacher_forcing_ratio
    
    if use_teacher_forcing:
        for di in range(target_length):
            # Forward step and loss
            decoder_output, decoer_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden_state, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            
            # Update input for next step (teacher-forcing)
            decoder_input = target_tensor[di]
    else:      
        for di in range(target_length):
            # Forward step and loss
            decoder_output, decoer_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden_state, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            
            # Update input for next step (using output at this step)
            log_likelihood, top_word = decoder_output.topk(1) 
            decoder_input = top_word.squeeze().detach()
            
            if decoder_input.item() == target_vocab.word2index['<EOS>']:
                break
    
    loss.backward()
    encoder_optimizer.step()
    decoder_optimizer.step()
    
    return loss.item() / target_length

# %%
def tensor2sentence(tensor, vocab):
    sent = []
    for i in tensor:
        sent.append(vocab.index2word[i.item()])
    return sent

# %%
def evaluate_model(encoder, decoder, input_tensor, target_tensor, max_length):
    
    with torch.no_grad():

        encoder_hidden_state = encoder.init_hidden()

        input_length = input_tensor.shape[0]
        target_length = target_tensor.shape[0]

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size)

        # Encode input tensor
        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden_state)
            encoder_outputs[ei] = encoder_output

        # Decode input tensor, seeding the decoding with the <BOS> token
        decoder_input = torch.tensor([[target_vocab.word2index['<SOS>']]])
        decoder_hidden_state = encoder_hidden_state
        decoder_word_outputs = []

        for di in range(target_length):
            # Forward step and loss
            decoder_output, decoer_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden_state, encoder_outputs)

            # Update input for next step (using output at this step)
            log_likelihood, top_word = decoder_output.topk(1) 
            decoder_input = top_word.squeeze().detach()
            decoder_word_output = target_vocab.index2word[decoder_input.item()]
            decoder_word_outputs.append(decoder_word_output)
            if decoder_word_output == '<EOS>':
                break
                

        print("Input: ", " ".join(tensor2sentence(input_tensor, input_vocab)))
        print("Target: ", " ".join(tensor2sentence(target_tensor, target_vocab)))
        print("Result: ", " ".join(decoder_word_outputs))

# %%
encoder = EncoderRNN(input_vocab.n_words, 100)
decoder = DecoderRNNAttention(target_vocab.n_words, 100, .1, max_seq_len+1)

# %%
encoder_optimizer = torch.optim.Adam(encoder.parameters())
decoder_optimizer = torch.optim.Adam(decoder.parameters())

criterion = nn.NLLLoss()

# %%
from tqdm import tqdm

# %%
def train_iteratively(encoder, decoder, tensor_pairs, encoder_optimizer, 
                    decoder_optimizer, criterion, max_length, validation_pairs,
                    teacher_forcing_ratio = 1.0, epochs = 2):
    
    for epoch in range(epochs):
        print("Epoch %d / %d" % (epoch + 1, epochs))
        loss = 0
        for input_tensor, target_tensor in tqdm(tensor_pairs):
            
            loss += train_model(encoder, decoder, input_tensor, target_tensor, encoder_optimizer, 
                         decoder_optimizer, criterion, max_length, teacher_forcing_ratio)
        
        
        # Print some statistics every epoch
        epoch_loss = loss / len(tensor_pairs)
        print('Loss: {:.4f}'.format(epoch_loss))
        
        # Print some examples after each epoch
        # TODO: Don't just print the first 10 sentences of the validation set...
        for input_tensor, target_tensor in validation_pairs[:10]:
            evaluate_model(encoder, decoder, input_tensor, target_tensor, max_length)
            print("")
        print("")

# %%
def evaluate(encoder, decoder, tensor_pairs,  max_length):
    

    for input_tensor, target_tensor in tensor_pairs:
        evaluate_model(encoder, decoder, input_tensor, target_tensor, max_length)
        print("")

# %%
training_sentences = zip(input_train, target_train)
validation_sentences = zip(input_val, target_val)

training_tensors = [pair2tensor(sent_pair) for sent_pair in training_sentences]
validation_tensors = [pair2tensor(sent_pair) for sent_pair in validation_sentences]

# %% [markdown]
# My training setup could definitely be improved, but I can't spend to mucg time per coding session writing boilerplate.
# I'll improve it iteratively over coming projects!
#
# Let's launch training!

# %%
train_iteratively(encoder, decoder, training_tensors, encoder_optimizer, decoder_optimizer, criterion, max_seq_len+1, validation_tensors)
# Out:
# Epoch 1 / 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:30<00:00, 26.52it/s]
# Loss: 3.4339
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är på . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är på . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är på . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är på . <EOS>
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är på . <EOS>
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är inte . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är på . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  de är inte . <EOS>
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  han är inte . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är inte . <EOS>
#
#
# Epoch 2 / 2
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:31<00:00, 25.59it/s]
# Loss: 2.6232
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är på att du
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är tystlåten . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är på övervåningen .
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är på att du är
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är på övervåningen . <EOS>
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är lite . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är på övervåningen . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  de är inte så inte död
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  han är stolt . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är lata . <EOS>

# %%
train_iteratively(encoder, decoder, training_tensors, encoder_optimizer, decoder_optimizer, criterion, max_seq_len+1, validation_tensors, epochs=5)
# Out:
# Epoch 1 / 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:34<00:00, 23.29it/s]
# Loss: 2.2548
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är från att .
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är ung . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är gräsliga . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från kanada . <EOS>
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid på polisstationen . <EOS>
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är ung . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid på övervåningen . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  de är inte död inte död
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  han är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är kall . <EOS>
#
#
# Epoch 2 / 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:36<00:00, 22.18it/s]
# Loss: 1.9425
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är på . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är ung . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är barfota . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från kanada . <EOS>
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid bort han är alltid bort fel buss
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är ung dit . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid bort . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  vi är inte död . <EOS>
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  han är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är kall . <EOS>
#
#
# Epoch 3 / 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:38<00:00, 21.03it/s]
# Loss: 1.6537
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är sen . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är ung . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är barfota . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från kanada . <EOS>
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid bort mot fram emot att få höra
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är ung . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid på scenen . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  vi är inte död . <EOS>
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  hon är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är kall . <EOS>
#
#
# Epoch 4 / 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:36<00:00, 21.88it/s]
# Loss: 1.4145
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är sen . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är ung . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är nykter . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från kanada på humör
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid ivrig . <EOS>
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är alltid på sjukhuset . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid bort . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  vi är inte död , .
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  hon är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är kall . <EOS>
#
#
# Epoch 5 / 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:33<00:00, 23.61it/s]
# Loss: 1.2163
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är sen . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är nyfiken . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är österrikare . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från kanada på humör
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid punktlig som dag . <EOS>
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är alltid ivrig . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid ivrig . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  vi är inte varit . <EOS>
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  hon är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är angelägen . <EOS>

# %%
train_iteratively(encoder, decoder, training_tensors, encoder_optimizer, decoder_optimizer, criterion, max_seq_len+1, validation_tensors, epochs=5)
# Out:
# Epoch 1 / 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:31<00:00, 25.01it/s]
# Loss: 1.0607
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är sen . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är dit . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är nykter . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från humör till .
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid punktlig eller hur ? <EOS>
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är alltid tillbaka dit . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid på scenen . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  vi är inte varit . <EOS>
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  hon är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är angelägen . <EOS>
#
#
# Epoch 2 / 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:31<00:00, 25.48it/s]
# Loss: 0.9144
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är sen . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är dit . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är österrikare . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från humör just .
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid punktlig . <EOS>
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är ung alltid ivrig att dö .
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid ivrig . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  vi är inte varit . <EOS>
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  hon är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är anpassningsbara . <EOS>
#
#
# Epoch 3 / 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:31<00:00, 25.75it/s]
# Loss: 0.8039
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är sen . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är nyfiken . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är nog . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från kanada . <EOS>
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid punktlig eller hur samma sak människor .
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är alltid på dåligt barn . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid på scenen . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  vi är inte varit . <EOS>
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  hon är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är kall . <EOS>
#
#
# Epoch 4 / 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:34<00:00, 23.44it/s]
# Loss: 0.7132
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är sen . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är nyfiken . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är nog . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från turkiet . <EOS>
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid punktlig sitt paraply inne rikaste man fel
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är alltid ivrig . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid ivrig . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  vi tänker inte yngre än så
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  hon är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är blå . <EOS>
#
#
# Epoch 5 / 5
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:39<00:00, 20.09it/s]
# Loss: 0.6295
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är sen . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är dit . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är banta . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från turkiet . <EOS>
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid punktlig som dag man fel buss .
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är alltid tillbaka imorgon . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid på scenen . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  vi är inte yngre än så
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  hon är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är kall . <EOS>

# %% [markdown]
# This time around I actually see some succesfull translations. However, I think the model is quickly overfitting to th training data, without improving on the validation set.
#
# I should have computed the validation loss to easier verify this...
#
# Let's print some more examples, as the 10 I have chosen arbitrarily are not all that interesting.

# %%
evaluate(encoder, decoder, validation_tensors, max_seq_len+1)
# Out:
# Input:  i 'm late . <EOS>
# Target:  jag är sen . <EOS>
# Result:  jag är sen . <EOS>
#
# Input:  he is handsome . <EOS>
# Target:  han är stilig . <EOS>
# Result:  han är dit . <EOS>
#
# Input:  they 're stalling . <EOS>
# Target:  de slingrar sig . <EOS>
# Result:  de är banta . <EOS>
#
# Input:  i 'm from kyoto . <EOS>
# Target:  jag är från kyoto . <EOS>
# Result:  jag är från kanada . <EOS>
#
# Input:  he is always throwing his weight around . <EOS>
# Target:  han håller jämt på och styr och ställer . <EOS>
# Result:  han är alltid punktlig så söt eller tokig . <EOS>
#
# Input:  he is suffering from a serious illness . <EOS>
# Target:  han lider av en svår sjukdom . <EOS>
# Result:  han är alltid från turkiet . <EOS>
#
# Input:  he is always complaining about his low salary . <EOS>
# Target:  han klagar jämt på sin låga lön . <EOS>
# Result:  han är alltid på scenen . <EOS>
#
# Input:  we 're not getting any younger . <EOS>
# Target:  vi blir inte yngre . <EOS>
# Result:  vi är inte yngre än .
#
# Input:  she is my girlfriend . <EOS>
# Target:  han är min vän . <EOS>
# Result:  hon är min typ . <EOS>
#
# Input:  i 'm horrible . <EOS>
# Target:  jag är hemsk . <EOS>
# Result:  jag är kall . <EOS>
#
# Input:  we 're not going to do that . <EOS>
# Target:  vi tänker inte göra det . <EOS>
# Result:  vi tänker inte sälja den . <EOS>
#
# Input:  he is my brother , not my father . <EOS>
# Target:  han är min bror , inte min far . <EOS>
# Result:  han är min far här är min far glad att
#
# Input:  i 'm very happy with my purchase . <EOS>
# Target:  jag är nöjd med mitt köp . <EOS>
# Result:  jag är mycket . <EOS>
#
# Input:  i 'm motivated . <EOS>
# Target:  jag är motiverad . <EOS>
# Result:  jag är nykter . <EOS>
#
# Input:  i 'm going into town . <EOS>
# Target:  jag åker in till stan . <EOS>
# Result:  jag är dit . <EOS>
#
# Input:  they 're working upstairs . <EOS>
# Target:  de jobbar på övervåningen . <EOS>
# Result:  de är på övervåningen . <EOS>
#
# Input:  we 're adaptable . <EOS>
# Target:  vi kan anpassa oss . <EOS>
# Result:  vi är anpassningsbara . <EOS>
#
# Input:  he is always kind to animals . <EOS>
# Target:  han är alltid snäll mot djur . <EOS>
# Result:  han är alltid sen till arbetet . <EOS>
#
# Input:  i 'm glad we did that . <EOS>
# Target:  jag är glad att vi gjorde det där . <EOS>
# Result:  jag är glad att vi är glad att vi är
#
# Input:  i am not romantic at all . <EOS>
# Target:  jag är inte alls romantisk . <EOS>
# Result:  jag är inte det . <EOS>
#
# Input:  i 'm going crazy . <EOS>
# Target:  jag blir galen . <EOS>
# Result:  jag är dit . <EOS>
#
# Input:  i 'm thinking of going to paris . <EOS>
# Target:  jag funderar på att åka till paris . <EOS>
# Result:  jag är båda . <EOS>
#
# Input:  we 're ready . <EOS>
# Target:  vi är redo . <EOS>
# Result:  vi är redo . <EOS>
#
# Input:  you are out of step . <EOS>
# Target:  du är i otakt . <EOS>
# Result:  du är på humör . <EOS>
#
# Input:  i am from russia . <EOS>
# Target:  jag är ifrån ryssland . <EOS>
# Result:  jag kommer ifrån turkiet . <EOS>
#
# Input:  i 'm not in on sunday . <EOS>
# Target:  jag är inte hemma nästa söndag . <EOS>
# Result:  jag är inte ont någonstans . <EOS>
#
# Input:  we 're ready . <EOS>
# Target:  vi är färdiga . <EOS>
# Result:  vi är redo . <EOS>
#
# Input:  i 'm speechless . <EOS>
# Target:  jag är mållös . <EOS>
# Result:  jag är gräsliga . <EOS>
#
# Input:  we are familiar with the legend of robin hood . <EOS>
# Target:  vi känner till legenden om robin hood . <EOS>
# Result:  vi är anpassningsbara . <EOS>
#
# Input:  we are n't serious . <EOS>
# Target:  vi är inte seriösa . <EOS>
# Result:  vi har inte ätit . <EOS>
#
# Input:  she is out now . <EOS>
# Target:  hon är ute nu . <EOS>
# Result:  hon är mycket äldre än .
#
# Input:  i 'm moving back home . <EOS>
# Target:  jag ska flytta tillbaka hem . <EOS>
# Result:  jag är dubbelt så söt . <EOS>
#
# Input:  i 'm on call today . <EOS>
# Target:  jag har bakjour i dag . <EOS>
# Result:  jag målar garaget . <EOS>
#
# Input:  i 'm your new partner . <EOS>
# Target:  jag är din nya partner . <EOS>
# Result:  jag är din advokat . <EOS>
#
# Input:  you are late . <EOS>
# Target:  du är sen . <EOS>
# Result:  du är sen . <EOS>
#
# Input:  i 'm glad i found you . <EOS>
# Target:  jag är glad att jag hittade er . <EOS>
# Result:  jag är glad att jag är här för det
#
# Input:  i 'm furious . <EOS>
# Target:  jag är rasande . <EOS>
# Result:  jag är ursinnig . <EOS>
#
# Input:  she 's worried about your safety . <EOS>
# Target:  hon är orolig över er säkerhet . <EOS>
# Result:  hon är orolig över din säkerhet . <EOS>
#
# Input:  we 're in trouble . <EOS>
# Target:  vi har råkat illa ut . <EOS>
# Result:  vi är på insidan . <EOS>
#
# Input:  i 'm at the north gate . <EOS>
# Target:  jag är vid den norra grinden . <EOS>
# Result:  jag är hemma . <EOS>
#
# Input:  we 're not sure . <EOS>
# Target:  vi är inte säkra . <EOS>
# Result:  vi är inte rädd för .
#
# Input:  we 're going to search the whole ship . <EOS>
# Target:  vi ska söka genom hela skeppet . <EOS>
# Result:  vi ska ändra på stationen klockan från arbetet
#
# Input:  i 'm working here now . <EOS>
# Target:  jag arbetar här nu . <EOS>
# Result:  jag är på polisstationen . <EOS>
#
# Input:  we 're out of milk . <EOS>
# Target:  vi har slut på mjölk . <EOS>
# Result:  vi är faktiskt ganska trött på tv
#
# Input:  i 'm a little early . <EOS>
# Target:  jag är lite tidig . <EOS>
# Result:  jag är lite tokig . <EOS>
#
# Input:  i 'm too young . <EOS>
# Target:  jag är för ung . <EOS>
# Result:  jag är här . <EOS>
#
# Input:  i 'm fairly hungry . <EOS>
# Target:  jag är tämligen hungrig . <EOS>
# Result:  jag är rätt hungrig . <EOS>
#
# Input:  i 'm not interested . <EOS>
# Target:  jag är inte intresserad . <EOS>
# Result:  jag är inte intresserad . <EOS>
#
# Input:  i 'm ready ! <EOS>
# Target:  jag är redo ! <EOS>
# Result:  jag är redo ! <EOS>
#
# Input:  i 'm going to throw tom out . <EOS>
# Target:  jag tänker kasta ut tom . <EOS>
# Result:  jag ska ändra på väg er .
#
# Input:  they 're all the same . <EOS>
# Target:  de är likadana allihop . <EOS>
# Result:  de är alla barfota allihop .
#
# Input:  she 's married to a dentist . <EOS>
# Target:  hon är gift med en tandläkare . <EOS>
# Result:  hon är ung dit . <EOS>
#
# Input:  i am playing guitar . <EOS>
# Target:  jag spelar gitarr . <EOS>
# Result:  jag är döende . <EOS>
#
# Input:  they 're going to enlarge their store . <EOS>
# Target:  de kommer att bygga ut sin butik . <EOS>
# Result:  de är dit . <EOS>
#
# Input:  he is better off than ever before . <EOS>
# Target:  han har det bättre än någonsin . <EOS>
# Result:  han är bättre än henne . <EOS>
#
# Input:  i 'm going to try . <EOS>
# Target:  jag kommer att försöka . <EOS>
# Result:  jag kommer att åka hem .
#
# Input:  i 'm almost sure of it . <EOS>
# Target:  jag är nästan säker på det . <EOS>
# Result:  jag är nästan aldrig hemma på skolan .
#
# Input:  we 're coming with you , tom . <EOS>
# Target:  vi följer med dig , tom . <EOS>
# Result:  vi tänker med er . <EOS>
#
# Input:  i 'm going to stay . <EOS>
# Target:  jag tänker stanna . <EOS>
# Result:  jag kommer att åka hem
#
# Input:  we 're already good friends . <EOS>
# Target:  vi är redan goda vänner . <EOS>
# Result:  vi är redan . <EOS>
#
# Input:  they 're broke . <EOS>
# Target:  de är barskrapade . <EOS>
# Result:  de är panka . <EOS>
#
# Input:  they 're suffering from malaria . <EOS>
# Target:  de lider av malaria . <EOS>
# Result:  de är alltid rätt . <EOS>
#
# Input:  we 're escaping . <EOS>
# Target:  vi flyr . <EOS>
# Result:  vi är skrattar .
#
# Input:  i 'm used to drinking coffee without sugar . <EOS>
# Target:  jag är van vid att dricka kaffe utan socker . <EOS>
# Result:  jag ska ha roligt . <EOS>
#
# Input:  i 'm in hong kong right now . <EOS>
# Target:  jag är i hong kong just nu . <EOS>
# Result:  jag är på polisstationen . <EOS>
#
# Input:  i 'm going to the gym . <EOS>
# Target:  jag går till gymmet . <EOS>
# Result:  jag kommer att åka dit .
#
# Input:  i 'm headed for my sister 's wedding . <EOS>
# Target:  jag är på väg till min systers bröllop . <EOS>
# Result:  jag är syskon . <EOS>
#
# Input:  i 'm looking for my key . <EOS>
# Target:  jag letar efter min nyckel . <EOS>
# Result:  jag ser fram emot det här för
#
# Input:  we 're going to finish this . <EOS>
# Target:  vi ska slutföra det här . <EOS>
# Result:  vi ska ändra på tv här .
#
# Input:  i 'm ready if you are . <EOS>
# Target:  jag är redo om ni är det . <EOS>
# Result:  jag är redo om du är redo om du
#
# Input:  i 'm mad at you . <EOS>
# Target:  jag är arg på dig . <EOS>
# Result:  jag är här för er . <EOS>
#
# Input:  they are my grandfather 's books . <EOS>
# Target:  de är min morfars böcker . <EOS>
# Result:  de är min farfars böcker . <EOS>
#
# Input:  i 'm glad tom has gone . <EOS>
# Target:  jag är glad att tom är borta . <EOS>
# Result:  jag är glad att tom . <EOS>
#
# Input:  they 're not busy . <EOS>
# Target:  de är inte upptagna . <EOS>
# Result:  de är inte upptagen . <EOS>
#
# Input:  he 's strong . <EOS>
# Target:  han är stark . <EOS>
# Result:  han är här . <EOS>
#
# Input:  we are men . <EOS>
# Target:  vi är män . <EOS>
# Result:  vi är hungrig . <EOS>
#
# Input:  i 'm so proud of you . <EOS>
# Target:  jag är så stolt över dig . <EOS>
# Result:  jag är så söt er allihop . <EOS>
#
# Input:  he is always making a fool of me . <EOS>
# Target:  han driver alltid med mig . <EOS>
# Result:  han är alltid rätt alltid punktlig en
#
# Input:  i 'm painting easter eggs . <EOS>
# Target:  jag målar påskägg . <EOS>
# Result:  jag kommer jämt dit .
#
# Input:  i 'm not an expert . <EOS>
# Target:  jag är inte någon expert . <EOS>
# Result:  jag är inte det . <EOS>
#
# Input:  you are one of us . <EOS>
# Target:  du är en av oss . <EOS>
# Result:  du är en främling här . <EOS>
#
# Input:  he is good at singing . <EOS>
# Target:  han är bra på att sjunga . <EOS>
# Result:  han är bra på polisstationen . <EOS>
#
# Input:  he 's always reading comics . <EOS>
# Target:  han läser alltid serietidningar . <EOS>
# Result:  han är alltid på tv .
#
# Input:  he 's studying . <EOS>
# Target:  han pluggar . <EOS>
# Result:  han är dit .
#
# Input:  we 're not going to sell it . <EOS>
# Target:  vi kommer inte att sälja den . <EOS>
# Result:  vi tänker inte sälja den . <EOS>
#
# Input:  i 'm just a friend . <EOS>
# Target:  jag är bara en kompis . <EOS>
# Result:  jag är bara en roman . <EOS>
#
# Input:  i 'm going back to bed . <EOS>
# Target:  jag går tillbaka till sängs . <EOS>
# Result:  jag är dit . <EOS>
#
# Input:  i am being followed . <EOS>
# Target:  jag är förföljd . <EOS>
# Result:  jag är färdiga . <EOS>
#
# Input:  i 'm no longer a rookie . <EOS>
# Target:  jag är ingen nybörjare längre . <EOS>
# Result:  jag är ingen tiggare . <EOS>
#
# Input:  he 's always late for class . <EOS>
# Target:  han är alltid sen till lektionen . <EOS>
# Result:  han är alltid sen pengar . <EOS>
#
# Input:  i 'm in a lot of pain . <EOS>
# Target:  jag har väldigt ont . <EOS>
# Result:  jag är på dåligt humör .
#
# Input:  he is always on the go . <EOS>
# Target:  han är alltid på väg någonstans . <EOS>
# Result:  han är alltid på scenen . <EOS>
#
# Input:  i 'm investigating a murder . <EOS>
# Target:  jag utreder ett mord . <EOS>
# Result:  jag är färdig . <EOS>
#
# Input:  you are the next in line for promotion . <EOS>
# Target:  du står näst på tur för en befordran . <EOS>
# Result:  du om tio är nyfiken . <EOS>
#
# Input:  we 're running late . <EOS>
# Target:  vi är sena . <EOS>
# Result:  vi kommer . <EOS>
#
# Input:  i 'm a little shook up . <EOS>
# Target:  jag är lite uppskakad . <EOS>
# Result:  jag är lite skakig . <EOS>
#
# Input:  i 'm still cooking the brown rice . <EOS>
# Target:  jag kokar fortfarande råriset . <EOS>
# Result:  jag är fortfarande geni att få
#
# Input:  i 'm no expert . <EOS>
# Target:  jag är inte någon expert . <EOS>
# Result:  jag är ingen tiggare . <EOS>
#
# Input:  i 'm not allowed to help you . <EOS>
# Target:  jag får inte hjälpa dig . <EOS>
# Result:  jag är inte död , om ursäkt
#
# Input:  i 'm fed up with eating in restaurants . <EOS>
# Target:  jag är trött på att äta på restaurang . <EOS>
# Result:  jag är mörkhyad . <EOS>
#
# Input:  i 'm glad to help . <EOS>
# Target:  det är roligt att kunna hjälpa till . <EOS>
# Result:  jag är glad att åka dit . <EOS>
#
# Input:  she is a good swimmer . <EOS>
# Target:  hon är en god simmare . <EOS>
# Result:  hon är lite skakig . <EOS>
#
# Input:  he is wearing glasses . <EOS>
# Target:  han har på sig glasögon . <EOS>
# Result:  han är på polisstationen . <EOS>
#
# Input:  they are vegetarians . <EOS>
# Target:  de är vegetarianer . <EOS>
# Result:  de närmar sig . <EOS>
#
# Input:  she is more wise than clever . <EOS>
# Target:  hon är mer vis än smart . <EOS>
# Result:  hon är noga . <EOS>
#
# Input:  i 'm getting hungry . <EOS>
# Target:  jag börjar bli hungrig . <EOS>
# Result:  jag är extremt hungrig . <EOS>
#
# Input:  i 'm resourceful . <EOS>
# Target:  jag är rådig . <EOS>
# Result:  jag är fyndig . <EOS>
#
# Input:  he 's dark and handsome . <EOS>
# Target:  han är mörk och snygg . <EOS>
# Result:  han är lata och jobbar . <EOS>
#
# Input:  he 's digging his own grave . <EOS>
# Target:  han gräver sin egen grav . <EOS>
# Result:  han är din säkerhet . <EOS>
#
# Input:  we 're going to do it again . <EOS>
# Target:  vi ska göra det igen . <EOS>
# Result:  vi ska ändra på tv . <EOS>
#
# Input:  she is after a better job . <EOS>
# Target:  hon är ute efter ett bättre jobb . <EOS>
# Result:  hon är ute en roman . <EOS>
#
# Input:  we 're going to find a cure . <EOS>
# Target:  vi ska hitta ett botemedel . <EOS>
# Result:  vi ska ändra på skolan . <EOS>
#
# Input:  i 'm sick of school . <EOS>
# Target:  jag är led på skolan . <EOS>
# Result:  jag är trött på skolan . <EOS>
#
# Input:  she is almost sixty years old . <EOS>
# Target:  hon är nästan sextio år gammal . <EOS>
# Result:  hon är nästan färdiga som dag och tyvärr
#
# Input:  i 'm getting a cat . <EOS>
# Target:  jag ska skaffa katt . <EOS>
# Result:  jag är extremt hungrig köpa mat
#
# Input:  i 'm a photographer . <EOS>
# Target:  jag är fotograf . <EOS>
# Result:  jag skriver ett sms en
#
# Input:  he is always at home on mondays . <EOS>
# Target:  han är alltid hemma på måndagar . <EOS>
# Result:  han är alltid på stationen . <EOS>
#
# Input:  i 'm happy to do it . <EOS>
# Target:  jag gör det gärna . <EOS>
# Result:  jag är lycklig på skolan .
#
# Input:  i 'm going to study english this afternoon . <EOS>
# Target:  jag ska studera engelska i eftermiddag . <EOS>
# Result:  jag kommer att åka dit på polisstationen .
#
# Input:  we are not americans . <EOS>
# Target:  vi är inte amerikaner . <EOS>
# Result:  vi är inte hungrig . <EOS>
#
# Input:  i 'm washing the dishes . <EOS>
# Target:  jag diskar . <EOS>
# Result:  jag är ont någonstans
#
# Input:  he is a poet . <EOS>
# Target:  han är en poet . <EOS>
# Result:  han är lite skakig . <EOS>
#
# Input:  i 'm good at my job . <EOS>
# Target:  jag är bra på mitt jobb . <EOS>
# Result:  jag är bra på min typ . <EOS>
#
# Input:  i 'm glad you noticed . <EOS>
# Target:  jag är glad att du lade märke till det . <EOS>
# Result:  jag undviker glad att hålla . <EOS>
#
# Input:  she is not as young as she looks . <EOS>
# Target:  hon är inte så ung som hon ser ut . <EOS>
# Result:  hon är inte som vi är inte som är inte det
#
# Input:  he 's always late for class . <EOS>
# Target:  han kommer alltid för sent till lektionen . <EOS>
# Result:  han är alltid sen pengar . <EOS>
#
# Input:  i am a vegetarian . <EOS>
# Target:  jag är vegetarian . <EOS>
# Result:  jag är lite skakig .
#
# Input:  he is digging his own grave . <EOS>
# Target:  han gräver sin egen grav . <EOS>
# Result:  han är din säkerhet . <EOS>
#
# Input:  i 'm not supposed to be doing this . <EOS>
# Target:  det är inte meningen att jag ska göra detta . <EOS>
# Result:  jag är inte död . <EOS>
#
# Input:  we 're going to be together . <EOS>
# Target:  vi kommer att vara tillsammans . <EOS>
# Result:  vi ska ändra på polisstationen . <EOS>
#
# Input:  i 'm next . <EOS>
# Target:  jag är nästa . <EOS>
# Result:  jag är angelägen . <EOS>
#
# Input:  i 'm going crazy . <EOS>
# Target:  jag håller på att bli galen . <EOS>
# Result:  jag är dit . <EOS>
#
# Input:  he is always asking for money . <EOS>
# Target:  han ber alltid om pengar . <EOS>
# Result:  han är alltid bort banta på stationen
#
# Input:  we 're going . <EOS>
# Target:  vi åker . <EOS>
# Result:  vi kommer att .
#
# Input:  we are to meet at seven . <EOS>
# Target:  vi ska mötas vid sju . <EOS>
# Result:  vi har gäster på polisstationen . <EOS>
#
# Input:  you are an angel for doing my shopping . <EOS>
# Target:  du är en ängel som handlar åt mig . <EOS>
# Result:  du . <EOS>
#
# Input:  they 're all barefoot . <EOS>
# Target:  de är barfota allesammans . <EOS>
# Result:  de är alla barfota allihop .
#
# Input:  i 'm just kidding you . <EOS>
# Target:  jag driver med dig bara . <EOS>
# Result:  jag semester i paris . <EOS>
#
# Input:  i 'm off beer . <EOS>
# Target:  jag har slutat med öl . <EOS>
# Result:  jag är ledig . <EOS>
# Input:  they are the ones who want to go . <EOS>
# Target:  det är de som vill gå . <EOS>
# Result:  de närmar sig . <EOS>
#
# Input:  i 'm your boss now . <EOS>
# Target:  jag är din chef nu . <EOS>
# Result:  jag är din advokat . <EOS>
#
# Input:  i 'm here every night . <EOS>
# Target:  jag är här varje kväll . <EOS>
# Result:  jag är här . <EOS>
#
# Input:  he 's good at cards . <EOS>
# Target:  han är duktig med kort . <EOS>
# Result:  han är bra på skolan . <EOS>
#
# Input:  i 'm not from a rich family . <EOS>
# Target:  jag kommer inte från en rik familj . <EOS>
# Result:  jag är inte härifrån . <EOS>
#
# Input:  we 're all related . <EOS>
# Target:  vi är alla släkt . <EOS>
# Result:  vi är alla lika . <EOS>
#
# Input:  i 'm glad we agree , tom . <EOS>
# Target:  jag är glad att vi är överens . <EOS>
# Result:  jag är här för detta glad att vi är
#
# Input:  i 'm so full . <EOS>
# Target:  jag är så mätt . <EOS>
# Result:  jag är så söt . <EOS>
#
# Input:  he 's the captain of a team . <EOS>
# Target:  han är lagkapten . <EOS>
# Result:  han är nyfiken . <EOS>
#
# Input:  i 'm headed that way . <EOS>
# Target:  jag är på väg åt det hållet . <EOS>
# Result:  jag är syskon . <EOS>
#
# Input:  i 'm going to cut down on meat . <EOS>
# Target:  jag kommer att skära ned på kött . <EOS>
# Result:  jag kommer att åka dit . <EOS>
#
# Input:  i am not going anywhere . <EOS>
# Target:  jag är inte på väg någonstans . <EOS>
# Result:  jag kommer inte sälja . <EOS>
#
# Input:  he is the champion . <EOS>
# Target:  han är segraren . <EOS>
# Result:  han är nyfiken . <EOS>
#
# Input:  i 'm very busy . <EOS>
# Target:  jag är väldigt upptagen . <EOS>
# Result:  jag är mycket människor . <EOS>
#
# Input:  we 're going . <EOS>
# Target:  vi ska gå . <EOS>
# Result:  vi är tillbaka dit .
#
# Input:  i 'm already rich . <EOS>
# Target:  jag är redan rik . <EOS>
# Result:  jag är redan hungrig . <EOS>
#
# Input:  i am going to paris this weekend . <EOS>
# Target:  jag ska till paris i helgen . <EOS>
# Result:  jag kommer att åka hem . <EOS>
#
# Input:  i 'm going with tom . <EOS>
# Target:  jag följer med tom . <EOS>
# Result:  jag kommer att ha nu .
#
# Input:  he is taller than his brother . <EOS>
# Target:  han är längre än sin bror . <EOS>
# Result:  han är från kanada . <EOS>
#
# Input:  we are in paris . <EOS>
# Target:  vi är i paris . <EOS>
# Result:  vi är på insidan . <EOS>
#
# Input:  i 'm going to fix it . <EOS>
# Target:  jag ska laga den . <EOS>
# Result:  jag ska ändra på mig .
#
# Input:  i 'm not hiding anything . <EOS>
# Target:  jag hemlighåller ingenting . <EOS>
# Result:  jag är inte död .
#
# Input:  i am a dog person . <EOS>
# Target:  jag är en hundmänniska . <EOS>
# Result:  jag är lite tokig . <EOS>
#
# Input:  he is just an amateur . <EOS>
# Target:  han är bara en amatör . <EOS>
# Result:  han är bara en vanlig kontorsråtta .
#
# Input:  we 're in the same business . <EOS>
# Target:  vi är i samma bransch . <EOS>
# Result:  vi är på stationen klockan på polisstationen
#
# Input:  they 're young . <EOS>
# Target:  de är unga . <EOS>
# Result:  de är ung . <EOS>
#
# Input:  he is an utter stranger to me . <EOS>
# Target:  han är en fullkomlig främling för mig . <EOS>
# Result:  han är en storätare . <EOS>
#
# Input:  he 's always late for class . <EOS>
# Target:  han kommer alltid för sent till timmen . <EOS>
# Result:  han är alltid sen till skolan . <EOS>
#
# Input:  i 'm highly motivated . <EOS>
# Target:  jag är väldigt motiverad . <EOS>
# Result:  jag är kall . <EOS>
#
# Input:  i am very happy in georgia . <EOS>
# Target:  jag trivs verkligen i georgien . <EOS>
# Result:  jag är mycket glad att lära mig
#
# Input:  i 'm going to throw a party . <EOS>
# Target:  jag ska ha fest . <EOS>
# Result:  jag ska börja banta på dåligt
#
# Input:  i 'm not an expert . <EOS>
# Target:  jag är ingen expert . <EOS>
# Result:  jag är inte det . <EOS>
#
# Input:  i 'm not hungry . <EOS>
# Target:  jag är inte hungrig . <EOS>
# Result:  jag är inte hungrig . <EOS>
#
# Input:  i 'm artistic . <EOS>
# Target:  jag är konstnärligt lagd . <EOS>
# Result:  jag är dubbelt så söt .
#
# Input:  he is very fond of music . <EOS>
# Target:  han tycker mycket om musik . <EOS>
# Result:  han är mycket man det är mycket
#
# Input:  i am married and have two children . <EOS>
# Target:  jag är gift och har två barn . <EOS>
# Result:  jag är ung buss . <EOS>
#
# Input:  he is lying . <EOS>
# Target:  han ljuger . <EOS>
# Result:  han är skrattar .
#
# Input:  i 'm really busy at the moment . <EOS>
# Target:  jag är väldigt upptagen för tillfället . <EOS>
# Result:  jag är verkligen upptagna er . <EOS>
#
# Input:  i 'm busy now . <EOS>
# Target:  jag är upptagen nu . <EOS>
# Result:  jag är upptagen . <EOS>
#
# Input:  i 'm hardly ever home . <EOS>
# Target:  jag är så gott som aldrig hemma . <EOS>
# Result:  jag är nästan färdiga här . <EOS>
#
# Input:  i 'm not listening to you . <EOS>
# Target:  jag tänker inte lyssna på dig . <EOS>
# Result:  jag kommer inte varit . <EOS>
#
# Input:  we 're not that close . <EOS>
# Target:  vi är inte så nära . <EOS>
# Result:  vi är inte så orolig . <EOS>
#
# Input:  i 'm certain . <EOS>
# Target:  jag är säker . <EOS>
# Result:  jag är redo . <EOS>
#
# Input:  i 'm motivated . <EOS>
# Target:  jag är peppad . <EOS>
# Result:  jag är ung . <EOS>
#
# Input:  i 'm being picked up . <EOS>
# Target:  jag håller på att bli uppraggad . <EOS>
# Result:  jag blir upphämtad . <EOS>
#
# Input:  i 'm glad that 's done . <EOS>
# Target:  jag är glad att det är gjort . <EOS>
# Result:  jag är här . <EOS>
#
# Input:  i 'm staying here . <EOS>
# Target:  jag stannar här . <EOS>
# Result:  jag är hans . <EOS>
#
# Input:  i 'm near the train station . <EOS>
# Target:  jag är nära tågstationen . <EOS>
# Result:  jag är gräsliga arbetet . <EOS>
#
# Input:  we 're not even married yet . <EOS>
# Target:  vi är inte ens gifta ännu . <EOS>
# Result:  vi är inte ont . <EOS>
#
# Input:  i 'm going to study . <EOS>
# Target:  jag ska studera . <EOS>
# Result:  jag ska turkiet . <EOS>
#
# Input:  i 'm happy you 're here , tom . <EOS>
# Target:  jag är glad att du är här , tom . <EOS>
# Result:  jag är lycklig här . <EOS>
#
# Input:  he is my enemy . <EOS>
# Target:  han är min fiende . <EOS>
# Result:  han är min typ . <EOS>
#
# Input:  i 'm going to the store . <EOS>
# Target:  jag går till butiken . <EOS>
# Result:  jag kommer att åka dit .
#
# Input:  we 're asking the questions . <EOS>
# Target:  det är vi som ställer frågorna . <EOS>
# Result:  vi är ute efter . <EOS>
#
# Input:  we 're aware of the problem . <EOS>
# Target:  vi är medvetna om problemet . <EOS>
# Result:  vi är medveten är medveten . <EOS>
#
# Input:  we 're related by marriage . <EOS>
# Target:  vi är ingifta släktingar . <EOS>
# Result:  vi är ledig . <EOS>
#
# Input:  they 're on good terms with their neighbors . <EOS>
# Target:  de är på god fot med sina grannar . <EOS>
# Result:  de är på att köra bil . <EOS>
#
# Input:  i 'm just kidding you . <EOS>
# Target:  jag skojar bara med er . <EOS>
# Result:  jag driver bara . <EOS>
#
# Input:  i 'm not going to hurt you . <EOS>
# Target:  jag ska inte göra illa dig . <EOS>
# Result:  jag kommer inte sälja dig huset . <EOS>
#
# Input:  he is longing for city life . <EOS>
# Target:  han längtar efter stadslivet . <EOS>
# Result:  han är hemma . <EOS>
#
# Input:  she is my girlfriend . <EOS>
# Target:  hon är min flickvän . <EOS>
# Result:  hon är min typ . <EOS>
#
# Input:  we 're extremely busy . <EOS>
# Target:  vi är extremt upptagna . <EOS>
# Result:  vi är extremt hungrig . <EOS>
#
# Input:  i 'm getting better . <EOS>
# Target:  jag håller på att bli bättre . <EOS>
# Result:  jag är extremt hungrig . <EOS>
#
# Input:  i 'm canadian , too . <EOS>
# Target:  jag är också kanadensare . <EOS>
# Result:  jag är på skolan . <EOS>
#
# Input:  i 'm no expert . <EOS>
# Target:  jag är ingen expert . <EOS>
# Result:  jag är ingen tiggare . <EOS>
#
# Input:  he is no longer here . <EOS>
# Target:  han är inte här längre . <EOS>
# Result:  han är ingen sida . <EOS>
#
# Input:  i 'm afraid of spiders . <EOS>
# Target:  jag är rädd för spindlar . <EOS>
# Result:  jag är rädd för trött på skolan
#
# Input:  he is not wearing a hat . <EOS>
# Target:  han har inte på sig hatt . <EOS>
# Result:  han har inte på sig . <EOS>
#
# Input:  i 'm fine . <EOS>
# Target:  det är okej med mig . <EOS>
# Result:  jag är smart . <EOS>
#
# Input:  he 's a bit shy . <EOS>
# Target:  han är lite blyg av sig . <EOS>
# Result:  han är en roman . <EOS>
#
# Input:  i 'm not ready to die yet . <EOS>
# Target:  jag är inte beredd att dö än . <EOS>
# Result:  jag är inte beredd att dö . <EOS>
#
# Input:  i 'm glad we found you . <EOS>
# Target:  jag är glad att vi hittade dig . <EOS>
# Result:  jag är glad att vi träffades . <EOS>
#
# Input:  i 'm waiting for you in my room . <EOS>
# Target:  jag väntar på dig på mitt rum . <EOS>
# Result:  jag tänker föräldrar . <EOS>
#
# Input:  we 're different . <EOS>
# Target:  vi är olika . <EOS>
# Result:  vi är marys . <EOS>
#
# Input:  i 'm here , too . <EOS>
# Target:  jag är också här . <EOS>
# Result:  jag är här . <EOS>
#
# Input:  i 'm going to try . <EOS>
# Target:  jag ska försöka . <EOS>
# Result:  jag kommer att åka .
#
# Input:  i 'm not prepared to compromise . <EOS>
# Target:  jag är inte beredd att kompromissa . <EOS>
# Result:  jag är inte ! inte det . <EOS>
#
# Input:  he is always speaking ill of his wife . <EOS>
# Target:  han talar alltid illa om sin fru . <EOS>
# Result:  han är alltid dumma frågor . <EOS>
#
# Input:  he 's a drama queen . <EOS>
# Target:  han är en drama queen . <EOS>
# Result:  han är lite skakig . <EOS>
#
# Input:  i 'm open to anything . <EOS>
# Target:  jag är öppen för vad som helst . <EOS>
# Result:  jag ska precis här för sent till arbetet .
#
# Input:  i 'm glad you remember . <EOS>
# Target:  det gläder mig att du minns . <EOS>
# Result:  jag är glad att ni minns . <EOS>
#
# Input:  we 're finished . <EOS>
# Target:  vi är färdiga . <EOS>
# Result:  vi är färdig . <EOS>
#
# Input:  i 'm a musician . <EOS>
# Target:  jag är musiker . <EOS>
# Result:  jag är lite hungrig .
#
# Input:  i am worried about him . <EOS>
# Target:  jag är orolig för honom . <EOS>
# Result:  jag är orolig för höjder . <EOS>
#
# Input:  i 'm just a taxi driver . <EOS>
# Target:  jag är bara en taxichaufför . <EOS>
# Result:  jag är bara en roman . <EOS>
#
# Input:  i 'm rested . <EOS>
# Target:  jag är utvilad . <EOS>
# Result:  jag är tacksam för .

# %% [markdown]
# There are some examples of perfect, or close translations! However, the model consequently fails at longer sentences and less common words. I think it is seriously suffering from the small data set. How can it learn to represent rare words like locations etc?
#
# So, I limited my data set to only include sentences with a limited structure, in this case they are only allowed to start with a few different word combinations. As far as I can see my model distinguishes well between the allowe starts!
# My problem is now instead that the model has trouble learning to translate the words beyond the start, as these can be fa more varied.
#
# Any translation model with a similar setup as mine will struggle with out of vocabulary words, since they never appear in the training data I would expect the model to never use them.
#
# A proper training set should be representative of the true data distribution. In a normal translation setting this data distribution should cover all english sentences and their swedish translation, in my fabriacted task it should be all english sentences starting with one of my chosen prefixes. Neither my original data set or my reduced set can get close to representing these distributions.
#
# Perhaps it's hopeless to train a translation system on data of such limied size as I am doing?
#
# I have many ideas I would like to incorporate, such as character embeddings and more regularization, but with my current results it would be hard to meassure their effect.
